# %% [raw]
# ---
# description: "Este m\xF3dulo concentra as constantes, fun\xE7\xF5es de carga, processamento,\
#   \ mesclagem e salvamento de dados aeron\xE1uticos provenientes da API do AisWeb"
# output-file: aisweb.html
# title: AISWEB
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## CONSTANTES

# %% [markdown]
# Dados para acesso à API AISWEB

# %%
#| echo: false
#| output: asis
show_doc(convert_longitude)
# Out:
# ---
#
# [source](https://github.com/InovaFiscaliza/EmissorasRF/blob/master/extracao/aero/icao.py#L33){target="_blank" style="float:right; font-size:smaller"}
#
# ### convert_longitude
#
# >      convert_longitude (lon:str)
#
# Converte a longitude para formato decimal
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | lon | str | Longitude |
# | **Returns** | **float** |  |

# %%
#| echo: false
#| output: asis
show_doc(convert_latitude)
# Out:
# ---
#
# [source](https://github.com/InovaFiscaliza/EmissorasRF/blob/master/extracao/aero/icao.py#L22){target="_blank" style="float:right; font-size:smaller"}
#
# ### convert_latitude
#
# >      convert_latitude (lat:str)
#
# Converte a Latitude para formato decimal
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | lat | str | Latitude |
# | **Returns** | **float** |  |

# %%
#| echo: false
#| output: asis
show_doc(AisWeb)
# Out:
# ---
#
# [source](https://github.com/InovaFiscaliza/EmissorasRF/blob/master/extracao/aero/aisweb.py#L53){target="_blank" style="float:right; font-size:smaller"}
#
# ### AisWeb
#
# >      AisWeb (api_key:str, api_pass:str, type_aero:Iterable[str]=['MIL',
# >              'PRIV/PUB', 'PUB', 'PUB/MIL', 'PUB/REST'])
#
# Classe para encapsular requisições REST à API do AISWEB
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | api_key | str |  | Chave API |
# | api_pass | str |  | Senha API |
# | type_aero | Iterable | ['MIL', 'PRIV/PUB', 'PUB', 'PUB/MIL', 'PUB/REST'] | Lista com os tipos de Aeroportos |

# %%
#| echo: false
#| output: asis
show_doc(get_aisw)
# Out:
# ---
#
# [source](https://github.com/InovaFiscaliza/EmissorasRF/blob/master/extracao/aero/aisweb.py#L213){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_aisw
#
# >      get_aisw ()
#
# Lê e processa os dataframes individuais da API AISWEB e retorna o conjunto concatenado

# %%
#| eval: false
get_aisw()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     Frequency             Latitude            Longitude  \
# 0       118.6      -3.145833333333              -59.985
# 1       109.3  -3.1502777777777777   -59.98222222222223
# 0       118.5     -29.945555555556     -51.143611111111
# 1       122.8     -29.945555555556     -51.143611111111
# 2       121.7     -29.945555555556     -51.143611111111
# ..        ...                  ...                  ...
# 502    1054.0  -22.796666666666667  -43.223888888888894
# 503       991  -22.796666666666667  -43.223888888888894
# 504     332.9  -22.804444444444446   -43.26416666666667
# 505    1076.0  -22.804444444444446   -43.26416666666667
# 506      1013  -22.804444444444446   -43.26416666666667
#
#                                            Description
# 0           [AISW] SBMN-COM, Torre, Campo Ponta Pelada
# 1    [AISW] SBMN-NAV, ILS/DME 09 IPE, Campo Ponta P...
# 0    [AISW] SBCO-COM, Torre, CAMPO NOSSA SENHORA DE...
# 1    [AISW] SBCO-COM, Torre, CAMPO NOSSA SENHORA DE...
# 2    [AISW] SBCO-COM, Solo, CAMPO NOSSA SENHORA DE ...
# ..                                                 ...
# 502  [DOC] SBGL-NAV, ILS 10 CAT II, Galeão - Antôni...
# 503  [DOC] SBGL-NAV, ILS 10 CAT II, Galeão - Antôni...
# 504  [DOC] SBGL-NAV, ILS/DME 28 ILM, Galeão - Antôn...
# 505  [DOC] SBGL-NAV, ILS/DME 28 ILM, Galeão - Antôn...
# 506  [DOC] SBGL-NAV, ILS/DME 28 ILM, Galeão - Antôn...
#
# [507 rows x 4 columns]
