# %% [raw]
# ---
# description: "M\xF3dulo de extra\xE7\xE3o e p\xF3s-processamento do Servi\xE7o M\xF3\
#   vel Pessoal"
# output-file: smp.html
# title: SMP
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
