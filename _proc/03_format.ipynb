# %% [raw]
# ---
# description: "Este m\xF3dulo possui fun\xE7\xF5es auxiliares de formata\xE7\xE3o dos\
#   \ dados das v\xE1rias fontes."
# output-file: format.html
# title: "Formata\xE7\xE3o"
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(parse_bw)
# Out:
# ---
#
# [source](https://github.com/InovaFiscaliza/EmissorasRF/blob/master/extracao/format.py#L35){target="_blank" style="float:right; font-size:smaller"}
#
# ### parse_bw
#
# >      parse_bw (bw:str)
#
# Parse the bandwidth string
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | bw | str | Designação de Emissão (Largura + Classe) codificada como string |
# | **Returns** | **Tuple** | **Largura e Classe de Emissão** |

# %% [markdown]
# ### Mesclagem
# Função auxiliar para mesclar registros que são iguais das diversas bases, i.e. estão a uma distância menor que `MAX_DIST` e verificar a validade da mesclagem

# %%
#| echo: false
#| output: asis
show_doc(merge_on_frequency)
# Out:
# ---
#
# [source](https://github.com/InovaFiscaliza/EmissorasRF/blob/master/extracao/format.py#L148){target="_blank" style="float:right; font-size:smaller"}
#
# ### merge_on_frequency
#
# >      merge_on_frequency (df_left:pandas.core.frame.DataFrame,
# >                          df_right:pandas.core.frame.DataFrame,
# >                          on:str='Frequency', coords:Tuple[str]=('Latitude',
# >                          'Longitude'), description:str='Description',
# >                          suffixes:Tuple[str]=('_x', '_y'))
#
# Mescla os dataframes baseados na frequência
# É assumido que as colunas de ambos uma é subconjunto ou idêntica à outra, caso contrário os filtros não irão funcionar como esperado
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | df_left | DataFrame |  | DataFrame da esquerda a ser mesclado |
# | df_right | DataFrame |  | DataFrame da direira a ser mesclado |
# ...

# %%
#| echo: false
#| output: asis
show_doc(get_km_distance)
# Out:
# ---
#
# [source](https://github.com/InovaFiscaliza/EmissorasRF/blob/master/extracao/format.py#L144){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_km_distance
#
# >      get_km_distance (row)

# %%
#| eval: false
folder = Path.cwd().parent / "dados"
