# %% [raw]
# ---
# description: "Este m\xF3dulo concentra as constantes, fun\xE7\xF5es de carga, processamento,\
#   \ mesclagem e salvamento de dados aeron\xE1uticos provenientes do Software Frequency\
#   \ Finder da ICAO"
# output-file: icao.html
# title: ICAO
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## CONSTANTES

# %% [markdown]
# Dados para acesso aos dados do ICAO

# %%
#| echo: false
#| output: asis
show_doc(convert_longitude)
# Out:
# ---
#
# [source](https://github.com/InovaFiscaliza/EmissorasRF/blob/master/extracao/aero/icao.py#L33){target="_blank" style="float:right; font-size:smaller"}
#
# ### convert_longitude
#
# >      convert_longitude (lon:str, hemisphere:str)
#
# Converte a longitude para formato decimal
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | lon | str | Longitude |
# | hemisphere | str | Hemisfério: W \| E |
# | **Returns** | **float** |  |

# %%
#| echo: false
#| output: asis
show_doc(convert_latitude)
# Out:
# ---
#
# [source](https://github.com/InovaFiscaliza/EmissorasRF/blob/master/extracao/aero/icao.py#L22){target="_blank" style="float:right; font-size:smaller"}
#
# ### convert_latitude
#
# >      convert_latitude (lat:str, hemisphere:str)
#
# Converte a Latitude para formato decimal
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | lat | str | Latitude |
# | hemisphere | str | Hemisfério: N \| S |
# | **Returns** | **float** |  |

# %%
from fastcore.test import test_close

# %%
lat = "25D36'01"
long = "056D06'00"
test_close(convert_latitude(lat, 'S'), -25.60027)
test_close(convert_longitude(long, 'W'), -56.10000)

# %%
#| echo: false
#| output: asis
show_doc(map_channels)
# Out:
# ---
#
# [source](https://github.com/InovaFiscaliza/EmissorasRF/blob/master/extracao/aero/icao.py#L63){target="_blank" style="float:right; font-size:smaller"}
#
# ### map_channels
#
# >      map_channels (df:pandas.core.frame.DataFrame, origem:str)
#
# Mapeia os canais contidos em `df` e adiciona os registros ILS/DME caso houver
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | df | DataFrame | DataFrame dos dados de origem |
# | origem | str | Descrição da emissão a ser substituída |
# | **Returns** | **DataFrame** |  |

# %%
#| echo: false
#| output: asis
show_doc(get_icao)
# Out:
# ---
#
# [source](https://github.com/InovaFiscaliza/EmissorasRF/blob/master/extracao/aero/icao.py#L90){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_icao
#
# >      get_icao ()
#
# Lê, concatena e pós-processa os arquivos do ICAO

# %%
#| eval: false
get_icao()
# Out:
#      Frequency             Latitude            Longitude  \
# 0        113.4   -9.866666666666667                -56.1
# 1        113.2                -3.25               -52.25
# 2        117.5   -4.183333333333334   -69.93333333333334
# 3        115.4               -16.25                -49.0
# 4        112.0  -10.983333333333333   -37.06666666666667
# ...        ...                  ...                  ...
# 2626      1176  -20.766666666666666               -51.55
# 2627    1082.0                -12.7  -60.083333333333336
# 2628      1019                -12.7  -60.083333333333336
# 2629    1126.0               -20.25   -40.28333333333333
# 2630      1189               -20.25   -40.28333333333333
#
#                                             Description
# 0                         [ICAO] VOR/DME, ALTA FLORESTA
# 1                              [ICAO] VOR/DME, ALTAMIRA
# 2                             [ICAO] VOR/DME, AMAZONICA
# ...
