# %% [raw]
# ---
# description: "M\xF3dulo para encapsular a cria\xE7\xE3o de conectores de banco com\
#   \ o intuito de serem usados por composi\xE7\xE3o nas classes de extra\xE7\xE3o de\
#   \ dados"
# output-file: connectors.html
# title: Conectores
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
# Insert in Path Project Directory
sys.path.insert(0, str(Path().cwd().parent))
os.chdir(Path.cwd().parent / 'extracao')
