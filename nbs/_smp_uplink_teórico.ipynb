# | 4         |           2515   |         2520   |             2635   |           2640   | 2500-2690 |
# | 5         |           2520   |         2525   |             2640   |           2645   | 2500-2690 |
# | 6         |           2525   |         2530   |             2645   |           2650   | 2500-2690 |
# | 7         |           2530   |         2535   |             2650   |           2655   | 2500-2690 |
# | 8         |           2535   |         2540   |             2655   |           2660   | 2500-2690 |
# | 9         |           2540   |         2545   |             2660   |           2665   | 2500-2690 |
# | 10        |           2545   |         2550   |             2665   |           2670   | 2500-2690 |
# | 11        |           2550   |         2555   |             2670   |           2675   | 2500-2690 |
# | 12        |           2555   |         2560   |             2675   |           2680   | 2500-2690 |
# | 13        |           2560   |         2565   |             2680   |           2685   | 2500-2690 |
# | 14        |           2565   |         2570   |             2685   |           2690   | 2500-2690 |
# | 15        |           2570   |         2575   |             2570   |           2575   | 2500-2690 |
# | 16        |           2575   |         2580   |             2575   |           2580   | 2500-2690 |
# | 17        |           2580   |         2585   |             2580   |           2585   | 2500-2690 |
# | 18        |           2585   |         2590   |             2585   |           2590   | 2500-2690 |
# | 19        |           2590   |         2595   |             2590   |           2595   | 2500-2690 |
# | 20        |           2595   |         2600   |             2595   |           2600   | 2500-2690 |
# | 21        |           2600   |         2605   |             2600   |           2605   | 2500-2690 |
# | 22        |           2605   |         2610   |             2605   |           2610   | 2500-2690 |
# | 23        |           2610   |         2615   |             2610   |           2615   | 2500-2690 |
# | 24        |           2615   |         2620   |             2615   |           2620   | 2500-2690 |
# | C-3       |            nan   |          nan   |             2570   |           2576   | 2570-2618 |
# | C-4       |            nan   |          nan   |             2582   |           2588   | 2570-2618 |
# | D-3       |            nan   |          nan   |             2576   |           2582   | 2570-2618 |
# | D-4       |            nan   |          nan   |             2588   |           2594   | 2570-2618 |
# | E-1       |            nan   |          nan   |             2594   |           2600   | 2570-2618 |
# | E-2       |            nan   |          nan   |             2606   |           2612   | 2570-2618 |
# | F-1       |            nan   |          nan   |             2600   |           2606   | 2570-2618 |
# | F-2       |            nan   |          nan   |             2612   |           2618   | 2570-2618 |

# %% [markdown]
# ## Processamento

# %%
import sys
from pathlib import Path
import pandas as pd
import numpy as np

# %%
sys.path.insert(0, str(Path().cwd().parent))
# %load_ext autoreload
# %autoreload 2

# %%
from extracao.format import parse_bw
from extracao.updates import split_designacao

# %%
COLS_SMP = {
    "NumAto": "Num_Ato",
    "NumFistel": "Fistel",
    "NomeEntidade": "Entidade",
    "SiglaUf": "UF",
    "NumEstacao": "Número_Estação",
    "CodMunicipio": "Código_Município",
    "DataValidade": "Validade_RF",
    "FreqInicialMHz": "Frequência_Inicial",
    "FreqCentralMHz": "Frequência_Central",
    "FreqTxMHz": "Frequência_Transmissão",
    "FreqRxMHz": "Frequência_Recepção",
    "FreqFinalMHz": "Frequência_Final",
    "formId": "Tipo_Estação",
    "Tecnologia": "Tecnologia",
    "Latitude": "Latitude",
    "Longitude": "Longitude",
    "DesignacaoEmissao": "Designação_Emissão",
    "PotenciaTransmissorWatts": "Potência(W)",
    "CodTipoAntena": "Cod_TipoAntena",
    "Polarizacao": "Polarização",
    "RaioAntena": "Raio_Antena",
    "GanhoAntena": "Ganho_Antena",
    "FrenteCostaAntena": "FC_Antena",
    "AnguloMeiaPotenciaAntena": "Ang_MP_Antena",
    "AnguloElevacao": "Ângulo_Elevação",
    "Azimute": "Azimute",
    "AlturaAntena": "Altura_Antena",
    "PerdasAcessorias": "Perdas_Acessorias",
}

DTYPE_SMP = {
    "NumAto": "category",
    "NumFistel": "category",
    "NomeEntidade": "category",
    "SiglaUf": "category",
    "NumEstacao": "string",
    "CodMunicipio": "category",
    "DataValidade": "category",
    "FreqInicialMHz": "category",
    "FreqCentralMHz": "category",
    "FreqFinalMHz": "category",
    "FreqTxMHz": "category",
    "FreqRxMHz": "category",
    "formId": "category",
    "Tecnologia": "category",
    "Latitude": "float",
    "Longitude": "float",
    "DesignacaoEmissao": "category",
    "PotenciaTransmissorWatts": "float",
    "CodTipoAntena": "category",
    "Polarizacao": "category",
    "RaioAntena": "float",
    "GanhoAntena": "float",
    "FrenteCostaAntena": "float",
    "AnguloMeiaPotenciaAntena": "float",
    "AnguloElevacao": "float",
    "Azimute": "float",
    "AlturaAntena": "float",
    "PerdasAcessorias": "float",
}

# %%
folder = Path.cwd().parent / 'dados'

# %%
df = pd.read_parquet(folder / 'smp_formated.parquet.gzip')

# %%
df = df.rename(columns=COLS_SMP)

# %%
df = split_designacao(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1946684 entries, 0 to 1946610
# Data columns (total 29 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Num_Ato                 string
#  1   Validade_RF             string
#  2   Fistel                  string
#  3   Entidade                string
#  4   Número_Estação          string
#  5   Latitude                string
#  6   Longitude               string
#  7   Frequência_Inicial      string
#  8   Frequência_Final        string
#  9   Frequência_Central      string
#  10  Código_Município        string
#  11  UF                      string
#  12  Potência(W)             string
#  13  Cod_TipoAntena          string
#  14  Polarização             string
#  15  Raio_Antena             string
#  16  Ganho_Antena            string
#  17  FC_Antena               string
#  18  Ang_MP_Antena           string
#  19  Ângulo_Elevação         string
#  20  Azimute                 string
#  21  Altura_Antena           string
#  22  Perdas_Acessorias       string
#  23  Tipo_Estação            string
#  24  Tecnologia              string
#  25  Frequência_Transmissão  string
#  26  Frequência_Recepção     string
#  27  Largura_Emissão(kHz)    string
#  28  Classe_Emissão          string
# dtypes: string(29)
# memory usage: 445.6 MB

# %% [markdown]
# A Frequência Central possui muitas lacunas nos dados, a frequência de transmissão será o dado utilizado.

# %%
df[df.Frequência_Central.isna()].shape
# Out:
# (591400, 29)

# %%
df[df.Frequência_Central == df.Frequência_Transmissão].shape
# Out:
# (297944, 29)

# %%
df[df.Frequência_Final == df.Frequência_Transmissão].shape
# Out:
# (626866, 29)

# %%
df[df.Frequência_Inicial == df.Frequência_Transmissão].shape
# Out:
# (24, 29)

# %% [markdown]
# Criar canais de Transmissão - Downlink

# %%
bw = df['Largura_Emissão(kHz)'].astype('float') / 2000 # Unidade em kHz
df['Início_Canal_Down'] = df.Frequência_Transmissão.astype(float) - bw 
df['Fim_Canal_Down'] = df.Frequência_Transmissão.astype(float) + bw
# df['Início_Canal_Up'] = df.Frequência_Recepção.astype(float) - bw 
# df['Fim_Canal_Up'] = df.Frequência_Recepção.astype(float) + bw

# %%
df.groupby(['Frequência_Transmissão'], as_index=False).size().sort_values('size', ascending=False)
# Out:
#    Frequência_Transmissão   size
# 98                  874.5  92135
# 61                 2160.0  87642
# 91                  788.0  69379
# 79                 2680.0  69357
# 55                 2140.0  63948
# ..                    ...    ...
# 99                  879.7      6
# 46                 1960.0      3
# 84                 3640.0      3
# 67                25400.0      2
# 70                25600.0      2
#
# [115 rows x 2 columns]

# %% [markdown]
# Eliminar colunas que não serão utilizadas

# %%
df.drop(['Frequência_Inicial', 'Frequência_Central', 'Frequência_Final'], axis=1, inplace=True)

# %% [markdown]
# Como vamos agrupar diversas estações baseadas em um subconjunto de colunas, vamos ordenar os dados de forma crescente pelo número da estação. Assim ao agruparmos diversos registros num só, o número da estação desse agrupamento será a estação licenciada mais antiga do grupo, em outras palavras, será mantido o número da estação menor por conta do ordenamento.

# %%
df['Número_Estação'] = df['Número_Estação'].astype(int) 
df = df.sort_values('Número_Estação', ignore_index=True)
df = df.astype('string')

# %%
subset = ['UF', 'Código_Município', 'Fistel', 'Frequência_Transmissão', 'Largura_Emissão(kHz)', 'Classe_Emissão']

# %% [markdown]
# É preciso eliminar dados vazios em qualquer das colunas que serão agrupadas, do contrário há um desalinhamento ao tentar juntar a contagem dos dados agregados.

# %%
df.dropna(subset=subset, axis=0, inplace=True)

# %%
df_sub = df[~df.duplicated(subset=subset, keep="first")].reset_index(drop=True)

# %%
df_sub['Multiplicidade'] = df.groupby(subset, sort=False).size().values

# %%
df_sub.sample(10)
# Out:
#             Num_Ato Validade_RF       Fistel                Entidade  \
# 140401   16952008.0  2023-04-30  50409889580              CLARO S.A.
# 58203      35352011  2023-04-30  50409889580              CLARO S.A.
# 5472       35312011  2023-04-30  50409146447  TELEFONICA BRASIL S.A.
# 94786    17012008.0  2023-04-30  50409146366  TELEFONICA BRASIL S.A.
# 85726   149592017.0  2032-12-18  50409889580              CLARO S.A.
# 116509     27882022  2028-11-29  50409146285  TELEFONICA BRASIL S.A.
# 16422      97812014  2029-12-08  50409428698                 TIM S/A
# 6686       59072012  2032-12-22  50409146285  TELEFONICA BRASIL S.A.
# 25743      46642011  2028-04-15  50409889580              CLARO S.A.
# 8898       41662008  2023-08-05  50409146447  TELEFONICA BRASIL S.A.
#
#        Número_Estação    Latitude   Longitude Código_Município  UF  \
# 140401     1014584350   -23.82247   -51.66603          4113106  PR
# 58203       685053148   -15.85472   -58.46528          5106828  MT
# 5472          5138221  -22.901397  -49.627597          3546405  SP
# 94786       691481954  -16.490472  -52.696278          5107198  MT
# 85726       690732368    -23.0936    -52.7868          4100905  PR
# 116509     1001813534   -21.70139   -42.96361          3140209  MG
# 16422       422351695   -12.14778       -45.0          2903201  BA
# 6686          5206200  -22.969203  -42.027906          3300258  RJ
# 25743       511472641       -29.4     -51.945          4301008  RS
# 8898        323763456  -23.322465  -46.236818          3546801  SP
#
#        Potência(W)  ... Perdas_Acessorias Tipo_Estação Tecnologia  \
# 140401        62.8  ...               0.0         base      WCDMA
# 58203         40.0  ...                 0         base        LTE
# 5472          40.0  ...               0.0         base        LTE
# 94786         40.0  ...               0.0         base      WCDMA
# 85726         40.0  ...                 0         base        LTE
# 116509        40.0  ...               0.0         base      WCDMA
# 16422           40  ...                           base        LTE
# 6686          46.1  ...               0.0         base        LTE
# 25743         20.0  ...                 0         base        GSM
# 8898          63.5  ...               0.0         base      WCDMA
#
#        Frequência_Transmissão Frequência_Recepção Largura_Emissão(kHz)  \
# 140401                 2130.0              1940.0               5000.0
# 58203                  1825.0              1820.0               5000.0
# 5472                   1867.5              1772.5               5000.0
# 94786                  2160.0              1970.0               5000.0
# 85726                  1880.0              1872.5               7500.0
# 116509                  885.0               840.0               5000.0
# 16422                   783.0               778.0               5000.0
# 6686                   2680.0              2560.0              20000.0
# 25743                  1880.0              1870.0                200.0
# 8898                    874.5               829.5               5000.0
#
#        Classe_Emissão Início_Canal_Down Fim_Canal_Down Multiplicidade
# 140401            D7W            2127.5         2132.5              6
# 58203             G7W            1822.5         1827.5              3
# 5472              G7W            1865.0         1870.0             15
# 94786             G7W            2157.5         2162.5              3
# 85726             G7W           1876.25        1883.75              3
# 116509            G7W             882.5          887.5              3
# 16422             G7W             780.5          785.5              3
# 6686              G7W            2670.0         2690.0             17
# 25743             G7W            1879.9         1880.1              6
# 8898              G7W             872.0          877.0             21
#
# [10 rows x 29 columns]

# %%
df_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142579 entries, 0 to 142578
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Num_Ato                 142579 non-null  string
#  1   Validade_RF             142579 non-null  string
#  2   Fistel                  142579 non-null  string
#  3   Entidade                142579 non-null  string
#  4   Número_Estação          142579 non-null  string
#  5   Latitude                142579 non-null  string
#  6   Longitude               142579 non-null  string
#  7   Código_Município        142579 non-null  string
#  8   UF                      142579 non-null  string
#  9   Potência(W)             142579 non-null  string
#  10  Cod_TipoAntena          142579 non-null  string
#  11  Polarização             142579 non-null  string
#  12  Raio_Antena             54888 non-null   string
#  13  Ganho_Antena            142579 non-null  string
#  14  FC_Antena               142579 non-null  string
#  15  Ang_MP_Antena           142579 non-null  string
#  16  Ângulo_Elevação         142579 non-null  string
#  17  Azimute                 142579 non-null  string
#  18  Altura_Antena           142579 non-null  string
#  19  Perdas_Acessorias       142579 non-null  string
#  20  Tipo_Estação            142579 non-null  string
#  21  Tecnologia              142579 non-null  string
#  22  Frequência_Transmissão  142579 non-null  string
#  23  Frequência_Recepção     142578 non-null  string
#  24  Largura_Emissão(kHz)    142579 non-null  string
#  25  Classe_Emissão          142579 non-null  string
#  26  Início_Canal_Down       142579 non-null  string
#  27  Fim_Canal_Down          142579 non-null  string
#  28  Multiplicidade          142579 non-null  int64
# dtypes: int64(1), string(28)
# memory usage: 31.5 MB

# %% [markdown]
# Lendo e formatando o arquivo de canais do serviço SMP, construído à partir da  [Resolução nº 757, de 08 de novembro de 2022](https://informacoes.anatel.gov.br/legislacao/resolucoes/2022/1760-resolucao-757)

# %%
canais = pd.read_excel(folder / 'canalização_smp.xlsx', dtype = 'string')
canais
# Out:
#         N_Bloco Uplink_Inicial Uplink_Final Downlink_Inicial Downlink_Final  \
# 0    1                  451           451.1              461          461.1
# 1    2                   451.1        451.2            461.1          461.2
# 2    3                   451.2        451.3            461.2          461.3
# 3    4                   451.3        451.4            461.3          461.4
# 4    5                   451.4        451.5            461.4          461.5
# ..          ...            ...          ...              ...            ...
# 142  20                2595         2600                2595           2600
# 143  21                2600         2605                2600           2605
# 144  22                2605         2610                2605           2610
# 145  23                2610         2615                2610           2615
# 146  24                2615         2620                2615           2620
#
#       Largura_Bloco(MHz) Offset       Faixa Tecnologia
# 0    0.10000000000002274     10  451-468           UHF
# 1     0.0999999999999659     10  451-468           UHF
# 2    0.10000000000002274     10  451-468           UHF
# 3     0.0999999999999659     10  451-468           UHF
# 4    0.10000000000002274     10  451-468           UHF
# ..                   ...    ...         ...        ...
# 142                    5      0  2500-2690     GSM|LTE
# 143                    5      0  2500-2690     GSM|LTE
# 144                    5      0  2500-2690     GSM|LTE
# 145                    5      0  2500-2690     GSM|LTE
# 146                    5      0  2500-2690     GSM|LTE
#
# [147 rows x 9 columns]

# %%
canais[['Downlink_Inicial', 'Downlink_Final']] = canais[['Downlink_Inicial', 'Downlink_Final']].astype(float)
canais[['Uplink_Inicial', 'Uplink_Final']] = canais[['Uplink_Inicial', 'Uplink_Final']].astype(float)
canais = canais.sort_values(['Downlink_Inicial'], ignore_index=True)
canais['N_Bloco'] = canais['N_Bloco'].str.strip()
canais['Faixa'] = canais['Faixa'].str.strip()

# %%
df_sub[['Início_Canal_Down', 'Fim_Canal_Down']] = df_sub[['Início_Canal_Down', 'Fim_Canal_Down']].astype(float)

# %%
conjunto_de_canais = df_sub.groupby(['Início_Canal_Down', 'Fim_Canal_Down']).size().to_frame('Total').reset_index()
conjunto_de_canais.sort_values('Total', ascending=False, inplace=True, ignore_index=True)
conjunto_de_canais
# Out:
#      Início_Canal_Down  Fim_Canal_Down  Total
# 0             872.0000        877.0000   4863
# 1             783.0000        793.0000   4071
# 2            2157.5000       2162.5000   3810
# 3             773.0000        783.0000   3652
# 4            2137.5000       2142.5000   2991
# ..                 ...             ...    ...
# 398          2665.0005       2664.9995      1
# 399          2665.7550       2674.2450      1
# 400          2649.8000       2660.2000      1
# 401          1817.5000       1827.5000      1
# 402          2355.0000       2385.0000      1
#
# [403 rows x 3 columns]

# %%
# from tqdm.auto import tqdm
# for row in tqdm(conjunto_de_canais.itertuples()):
#     for subset in canais.groupby('Faixa'):
#         canal, canais_subset = subset
#         begin = canais_subset[(row.Início_Canal >= canais_subset['Downlink_Inicial']) & (row.Início_Canal < canais_subset['Downlink_Final'])]
#         end = canais_subset[(row.Fim_Canal > canais_subset['Downlink_Inicial']) & (row.Fim_Canal <= canais_subset['Downlink_Final'])]
#         if not begin.empty and not end.empty:
#             blocos = '|'.join(canais_subset.loc[begin.index[0]:end.index[-1], 'N_Bloco'])
#             conjunto_de_canais.loc[row.Index, ['Blocos', 'Faixas']] = blocos, canal
#             break

# %%
# from tqdm.auto import tqdm
# for row in tqdm(conjunto_de_canais.itertuples()):
#     begin = canais[(row.Início_Canal >= canais['Downlink_Inicial']) & (row.Início_Canal < canais['Downlink_Final'])]
#     end = canais[(row.Fim_Canal > canais['Downlink_Inicial']) & (row.Fim_Canal <= canais['Downlink_Final'])]
#     if not begin.empty and not end.empty:
#         blocos = '|'.join(canais.loc[begin.index[0]:end.index[0], 'N_Bloco'])
#         faixas = '|'.join(canais.loc[begin.index[0]:end.index[0], 'Faixa'].unique())
#         conjunto_de_canais.loc[row.Index, ['Blocos', 'Faixas']] = blocos, faixas

# %%
from tqdm.auto import tqdm
conjunto_de_canais['Intervalo_Canal'] = 'Inválido'
for row in tqdm(conjunto_de_canais.itertuples()):
    interval = canais[(row.Início_Canal_Down < canais['Downlink_Final']) & (row.Fim_Canal_Down > canais['Downlink_Inicial'])]
    faixa = 'Downlink'
    if interval.empty:
        interval = canais[(row.Início_Canal_Down < canais['Uplink_Final']) & (row.Fim_Canal_Down > canais['Uplink_Inicial'])]
        faixa = 'Uplink'
    else:
        down = ' | '.join(interval[['Downlink_Inicial', 'Downlink_Final']].apply(lambda x: f'{x[0]}-{x[1]}', axis=1))
        faixas = ' | '.join(interval.Faixa.unique())
        offset = ' | '.join(interval.Offset.unique())
        conjunto_de_canais.loc[row.Index, ['Blocos_Downlink', 'Faixas', 'Intervalo_Canal', 'Offset']] = down, faixas, faixa, offset
# Out:
# 0it [00:00, ?it/s]

# %%
# conjunto_de_canais['Intervalo_Canal_Up'] = 'Inválido'
# for row in tqdm(conjunto_de_canais.itertuples()):
#     interval = canais[(row.Início_Canal_Up < canais['Uplink_Final']) & (row.Fim_Canal_Up > canais['Uplink_Inicial'])]
#     faixa = 'Uplink'
#     if interval.empty:
#         interval = canais[(row.Início_Canal_Up < canais['Downlink_Final']) & (row.Fim_Canal_Up > canais['Downlink_Inicial'])]
#         faixa = 'Downlink'
#     else:
#         up = ' | '.join(interval[['Uplink_Inicial', 'Uplink_Final']].apply(lambda x: f'{x[0]}-{x[1]}', axis=1))
#         faixas = ' | '.join(interval.Faixa.unique())
#         conjunto_de_canais.loc[row.Index, ['Blocos_Uplink', 'Faixas_Uplink', 'Intervalo_Canal_Up']] = up, faixas, faixa
# Out:
# 0it [00:00, ?it/s]

# %%
conjunto_de_canais = conjunto_de_canais[['Início_Canal_Down', 'Fim_Canal_Down', 'Blocos_Downlink', 'Faixas', 'Intervalo_Canal', 'Offset']]
# conjunto_de_canais.to_excel(folder / 'canais2canalização.xlsx', index=False)

# %%
conjunto_de_canais
# Out:
#      Início_Canal_Down  Fim_Canal_Down  \
# 0             872.0000        877.0000
# 1             783.0000        793.0000
# 2            2157.5000       2162.5000
# 3             773.0000        783.0000
# 4            2137.5000       2142.5000
# ..                 ...             ...
# 398          2665.0005       2664.9995
# 399          2665.7550       2674.2450
# 400          2649.8000       2660.2000
# 401          1817.5000       1827.5000
# 402          2355.0000       2385.0000
#
#                                        Blocos_Downlink     Faixas  \
# 0                            869.0-874.0 | 874.0-879.0    819-894
# 1                            783.0-788.0 | 788.0-793.0    703-803
# 2                        2155.0-2160.0 | 2160.0-2165.0  1920-2170
# 3                            773.0-778.0 | 778.0-783.0    703-803
# 4                        2135.0-2140.0 | 2140.0-2145.0  1920-2170
# ..                                                 ...        ...
# 398                                                NaN        NaN
# 399                      2665.0-2670.0 | 2670.0-2675.0  2500-2690
# 400  2645.0-2650.0 | 2650.0-2655.0 | 2655.0-2660.0 ...  2500-2690
# 401      1815.0-1820.0 | 1820.0-1825.0 | 1825.0-1830.0  1710-1880
# 402                                                NaN        NaN
#
#     Intervalo_Canal Offset  Total
# 0          Downlink     45   4863
# 1          Downlink     55   4071
# 2          Downlink    190   3810
# 3          Downlink     55   3652
# 4          Downlink    190   2991
# ..              ...    ...    ...
# 398        Inválido    NaN      1
# 399        Downlink    120      1
# 400        Downlink    120      1
# 401        Downlink     95      1
# 402        Inválido    NaN      1
#
# [403 rows x 7 columns]

# %%
conjunto_de_canais.Intervalo_Canal.value_counts()
# Out:
# Intervalo_Canal
# Downlink    367
# Inválido     36
# Name: count, dtype: int64

# %%
df_out = pd.merge(df_sub, conjunto_de_canais, how='left', on=['Início_Canal_Down', 'Fim_Canal_Down'])

# %% [markdown]
# Total de Agrupamentos Inválidos

# %%
df_out.Intervalo_Canal.value_counts()
# Out:
# Intervalo_Canal
# Downlink    141177
# Inválido      1402
# Name: count, dtype: int64

# %%
df_out.sample(5)
# Out:
#            Num_Ato Validade_RF       Fistel  \
# 18362   16992008.0  2023-04-30  50409314250
# 129144    73852008  2023-11-28  50409428698
# 5542      41662008  2023-04-30  50409146447
# 56522     35332011  2023-04-30  50409889580
# 109041    73852008  2023-11-28  50409428698
#
#                                                  Entidade Número_Estação  \
# 18362   TIM S A                                       ...      431354324
# 129144  TIM S A                                       ...     1011077172
# 5542                               TELEFONICA BRASIL S.A.        5139546
# 56522                                          CLARO S.A.      684998025
# 109041                                            TIM S/A      699269709
#
#           Latitude   Longitude Código_Município  UF Potência(W)  ...  \
# 18362   -27.052833  -49.523194          4206900  SC        60.0  ...
# 129144   -7.360489  -39.046559          2300101  CE        40.0  ...
# 5542    -22.415428  -50.578697          3535507  SP        35.0  ...
# 56522    -26.90221    -52.9127          4211405  SC        40.0  ...
# 109041   -4.100278  -40.428611          2312205  CE      80.000  ...
#
#        Largura_Emissão(kHz) Classe_Emissão Início_Canal_Down Fim_Canal_Down  \
# 18362                5000.0            G7W           2147.50        2152.50
# 129144              10000.0            G7W            869.50         879.50
# 5542                  200.0            G7W            890.65         890.85
# 56522                2500.0            G7W           1870.00        1872.50
# 109041               5000.0            G9W            877.50         882.50
#
#        Multiplicidade                          Blocos_Downlink     Faixas  \
# 18362               3            2145.0-2150.0 | 2150.0-2155.0  1920-2170
# 129144              3  869.0-874.0 | 874.0-879.0 | 879.0-884.0    819-894
# 5542               10                              889.0-894.0    819-894
# 56522               3                            1870.0-1875.0  1710-1880
# 109041              3                874.0-879.0 | 879.0-884.0    819-894
#
#        Intervalo_Canal Offset Total
# 18362         Downlink    190  1434
# 129144        Downlink     45   334
# 5542          Downlink     45  1044
# 56522         Downlink     95   278
# 109041        Downlink     45  1666
#
# [5 rows x 34 columns]

# %% [markdown]
# Total de Estações cuja Frequência de Transmissão não pertence a nenhum canal válido

# %%
df_out.loc[df_out.Intervalo_Canal == 'Inválido', 'Multiplicidade'].sum()
# Out:
# 49675

# %%
df_bad = df_out.loc[df_out.Intervalo_Canal == 'Inválido'].reset_index(drop=True)

# %% [markdown]
# Vamos excluir os registros inválidos do nosso resultado

# %%
df_out = df_out.loc[df_out.Intervalo_Canal != 'Inválido'].reset_index(drop=True)

# %%
df_out.Faixas.str.contains('\|').sum()
# Out:
# 467

# %% [markdown]
# Para checar que temos, conforme esperado, um offset único para dado conjunto de blocos que o canal está inserido. Em outras palavras, temos que garantir que o Canal, mesmo que ocupe mais de 1 bloco de frequência, ou mesmo mais de uma faixa da canalização.
#
# Por quê isso?
#
# Porque iremos utilizar esse offset para determinar a frequência de recepção teórica à partir da frequência de transmissão e para tal não faz sentido ter mais de 1 valor de offset.

# %%
df_out.Offset.str.contains('\|').sum()
# Out:
# 0

# %%
df_out['Frequência_Recepção_Teórica'] = df_out.Frequência_Transmissão.astype('float') - df_out.Offset.astype('float')

# %%
df_out.sample(10)
# Out:
#            Num_Ato Validade_RF       Fistel                Entidade  \
# 36835     35312011  2023-04-30  50409146366  TELEFÔNICA BRASIL S.A.
# 82836     59592012  2032-12-22  50409307637              CLARO S.A.
# 76755     48412023  2038-04-30  50409146285  TELEFONICA BRASIL S.A.
# 102959  16992008.0  2023-04-30  50010613854                 TIM S/A
# 132480  29272013.0  2023-04-30  50409314250                 TIM S A
# 19740     59592012  2027-10-18  50409889580              CLARO S.A.
# 44166     47102015  2031-03-11  50010613854                TIM S/A
# 1067      59072012  2038-04-30  50409146285  TELEFONICA BRASIL S.A.
# 58771     46662011  2027-08-06  50409105090              CLARO S.A.
# 121179    34672011  2026-06-01  50409307637              CLARO S.A.
#
#        Número_Estação      Latitude     Longitude Código_Município  UF  \
# 36835       682665274     -25.57917     -49.36528          4101804  PR
# 82836       690551711      -5.33864     -49.09152          1504208  PA
# 76755       689665296     -21.71694     -46.38583          3105301  MG
# 102959      695541218     -22.62889     -47.19861          3512803  SP
# 132480     1013053580  -27.50559444  -52.60624722          4302055  RS
# 19740       441537847     -28.38667     -53.89167          4310207  RS
# 44166       684046709     -20.75906     -49.70272          3531407  SP
# 1067           603368     -18.91611     -47.00583          3148103  MG
# 58771       686130588     -23.44389     -46.88278          3547304  SP
# 121179     1004125795      -7.50865     -63.03621          1301704  AM
#
#        Potência(W)  ... Classe_Emissão Início_Canal_Down Fim_Canal_Down  \
# 36835       39.500  ...            G7W            1859.9         1860.1
# 82836         60.0  ...            G7W            2630.0         2650.0
# 76755         40.0  ...            G9W            2157.5         2162.5
# 102959      61.500  ...            G7W            2132.5         2137.5
# 132480        40.0  ...            G7W            1825.0         1830.0
# 19740         40.0  ...            G7W            2640.0         2660.0
# 44166           80  ...            G7W            1824.9         1825.1
# 1067          80.0  ...            G7W            2670.0         2690.0
# 58771        45.91  ...            G9W             891.5          896.5
# 121179        60.0  ...            G7W            1850.0         1860.0
#
#        Multiplicidade                                    Blocos_Downlink  \
# 36835               3                      1855.0-1860.0 | 1860.0-1865.0
# 82836              54  2630.0-2635.0 | 2635.0-2640.0 | 2640.0-2645.0 ...
# 76755               2                      2155.0-2160.0 | 2160.0-2165.0
# 102959              3                      2130.0-2135.0 | 2135.0-2140.0
# 132480              3                                      1825.0-1830.0
# 19740              21  2640.0-2645.0 | 2645.0-2650.0 | 2650.0-2655.0 ...
# 44166               4                      1820.0-1825.0 | 1825.0-1830.0
# 1067               40  2670.0-2675.0 | 2675.0-2680.0 | 2680.0-2685.0 ...
# 58771               3                                        889.0-894.0
# 121179              3                      1850.0-1855.0 | 1855.0-1860.0
#
#            Faixas Intervalo_Canal Offset Total Frequência_Recepção_Teórica
# 36835   1710-1880        Downlink     95   404                      1765.0
# 82836   2500-2690        Downlink    120  1242                      2520.0
# 76755   1920-2170        Downlink    190  3810                      1970.0
# 102959  1920-2170        Downlink    190  2051                      1945.0
# 132480  1710-1880        Downlink     95   697                      1732.5
# 19740   2500-2690        Downlink    120  1166                      2530.0
# 44166   1710-1880        Downlink     95  1647                      1730.0
# 1067    2500-2690        Downlink    120  2734                      2560.0
# 58771     819-894        Downlink     45   555                       849.0
# 121179  1710-1880        Downlink     95  1962                      1760.0
#
# [10 rows x 35 columns]

# %%
df_out.Offset.value_counts()
# Out:
# Offset
# 95     55102
# 45     29658
# 190    26980
# 55     16303
# 120    13107
# 10        27
# Name: count, dtype: int64

# %%
(df_out.Multiplicidade == 1).sum()
# Out:
# 2510

# %%
df_out.to_parquet(folder / 'dados_smp_processados.parquet.gzip', compression='gzip')

# %%
df_out.columns
# Out:
# Index(['Num_Ato', 'Validade_RF', 'Fistel', 'Entidade', 'Número_Estação',
#        'Latitude', 'Longitude', 'Código_Município', 'UF', 'Potência(W)',
#        'Cod_TipoAntena', 'Polarização', 'Raio_Antena', 'Ganho_Antena',
#        'FC_Antena', 'Ang_MP_Antena', 'Ângulo_Elevação', 'Azimute',
#        'Altura_Antena', 'Perdas_Acessorias', 'Tipo_Estação', 'Tecnologia',
#        'Frequência_Transmissão', 'Frequência_Recepção', 'Largura_Emissão(kHz)',
#        'Classe_Emissão', 'Início_Canal_Down', 'Fim_Canal_Down',
#        'Multiplicidade', 'Blocos_Downlink', 'Faixas', 'Intervalo_Canal',
#        'Offset', 'Total', 'Frequência_Recepção_Teórica'],
#       dtype='object')

# %%
# ibge = pd.read_excel(folder / 'municipios_coordenadas.xlsx', dtype='string')
ibge = pd.read_csv(folder.parent / 'extracao' / 'arquivos' / 'municipios_ibge.csv', dtype='string')

# %%
ibge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   codigo_ibge  5570 non-null   string
#  1   nome         5570 non-null   string
#  2   latitude     5570 non-null   string
#  3   longitude    5570 non-null   string
#  4   capital      5570 non-null   string
#  5   codigo_uf    5570 non-null   string
# dtypes: string(6)
# memory usage: 261.2 KB

# %%
ibge.sample(5)
# Out:
#      codigo_ibge                    nome  latitude longitude capital codigo_uf
# 1151     2604106                 Caruaru  -8.28455  -35.9699       0        26
# 4756     2514404  São José de Espinharas  -6.83974  -37.3214       0        25
# 4064     4120804           Quatro Barras  -25.3673  -49.0763       0        41
# 1995     4109005               Guapirama  -23.5203  -50.0407       0        41
# 4972     1507805   Senador José Porfírio  -4.31242  -51.5764       0        15

# %%
ibge.columns = ['Código_Município', 'Município', 'Latitude', 'Longitude', 'Capital', 'Código_UF']

# %%
smp = pd.read_parquet(folder / 'dados_smp_processados.parquet.gzip').astype('string')

# %% [markdown]
# Os dados que foram agregados por `['UF', 'Código_Município', 'Fistel', 'Frequência_Transmissão', 'Largura_Emissão(kHz)', 'Classe_Emissão']`. A coluna `Multiplicidade` guarda a contagem de estações agrupadas para dado conjunto de valores dessas colunas.
#
# Para os registros que possuem `Multiplicidade=1`, não houve agregação e a estação é única. Para esses a coordenada da estação é mantida. Para todos os demais registros as coordenadas serão substituídas pela coordenada do município. Fazer processamento como imputar uma média das coordenadas não agrega valor "fiscalizatório" porque gera uma coordenada que não existe. A substituição pela coordenada central do município tem o propósito simplesmente de dar a localidade na qual aquele conjunto de estações serve.

# %%
coords_municipio = pd.merge(smp.loc[smp.Multiplicidade != '1', 'Código_Município'], ibge[['Código_Município', 'Latitude', 'Longitude']], 
                            on='Código_Município', 
                            how='left')

# %%
smp.loc[smp.Multiplicidade != '1', ['Latitude', 'Longitude']] = coords_municipio[['Latitude', 'Longitude']].values

# %%
smp['Coords_Valida_IBGE'] = '1'

# %%
smp.loc[smp.Multiplicidade != '1', 'Coords_Valida_IBGE'] = '0'

# %%
smp[['Latitude_IBGE', 'Longitude_IBGE']] = smp[['Latitude', 'Longitude']]

# %%
smp.sample(5)
# Out:
#             Num_Ato Validade_RF       Fistel                Entidade  \
# 1024      125002022  2028-11-29  50409314250                 TIM S A
# 140258     13652021  2023-04-30  50409146285  TELEFONICA BRASIL S.A.
# 109934  149592017.0  2032-12-18  50409889580              CLARO S.A.
# 85573      34672011  2026-06-01  50409307637              CLARO S.A.
# 46207    16952008.0  2032-12-12  50409307637              CLARO S.A.
#
#        Número_Estação  Latitude Longitude Código_Município  UF Potência(W)  \
# 1024           565490  -23.2659  -51.0522          4109807  PR        60.0
# 140258     1014937393  -6.48529  -37.4488          2513901  PB        40.0
# 109934      700009752  -25.8515  -52.5173          4105409  PR        40.0
# 85573       690761295  -4.09412  -63.1441          1301209  AM        60.0
# 46207       684357836  -10.4374  -39.3321          2921500  BA        50.0
#
#         ... Multiplicidade                Blocos_Downlink     Faixas  \
# 1024    ...              5  1820.0-1825.0 | 1825.0-1830.0  1710-1880
# 140258  ...              3  2125.0-2130.0 | 2130.0-2135.0  1920-2170
# 109934  ...              3                  1875.0-1880.0  1710-1880
# 85573   ...              3  1850.0-1855.0 | 1855.0-1860.0  1710-1880
# 46207   ...              3  2145.0-2150.0 | 2150.0-2155.0  1920-2170
#
#        Intervalo_Canal Offset Total Frequência_Recepção_Teórica  \
# 1024          Downlink     95  1647                      1730.0
# 140258        Downlink    190  2546                      1940.0
# 109934        Downlink     95  1872                      1785.0
# 85573         Downlink     95  1053                      1760.0
# 46207         Downlink    190  1434                      1960.0
#
#        Coords_Valida_IBGE Latitude_IBGE Longitude_IBGE
# 1024                    0      -23.2659       -51.0522
# 140258                  0      -6.48529       -37.4488
# 109934                  0      -25.8515       -52.5173
# 85573                   0      -4.09412       -63.1441
# 46207                   0      -10.4374       -39.3321
#
# [5 rows x 38 columns]

# %%
municipio = pd.merge(smp[['Código_Município']], ibge[['Código_Município', 'Município']], 
                            on='Código_Município', 
                            how='left')

# %%
municipio[municipio.Município.isna()]
# Out:
#        Código_Município Município
# 122060        3530607        <NA>
# 122061        3530607        <NA>

# %%
# municipio.loc[municipio.Município.isna(), 'Município'] = 'Mogi das Cruzes'

# %%
smp['Status'] = 'L'
smp['Num_Serviço'] = '010'

# %%
smp['Município_IBGE'] = municipio.Município.values

# %%
from extracao.format import merge_on_frequency, _filter_matlab, _format_matlab
from extracao.constants import COLUNAS

# %%
down = smp.rename(columns={'Frequência_Transmissão' : 'Frequência'}).copy()
down = down.drop('Frequência_Recepção_Teórica', axis=1)

# %%
down['Fonte'] = 'MOS'
down['Classe'] = 'FB'

# %%
up = smp.rename(columns={'Frequência_Recepção_Teórica' : 'Frequência'}).copy()
up = up.drop('Frequência_Transmissão', axis=1)

# %%
up['Fonte'] = 'DOC'
up['Classe'] = 'ML'

# %%
smp = pd.concat([down, up], ignore_index=True)

# %%
smp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282354 entries, 0 to 282353
# Data columns (total 42 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Num_Ato               282354 non-null  string
#  1   Validade_RF           282354 non-null  string
#  2   Fistel                282354 non-null  string
#  3   Entidade              282354 non-null  string
#  4   Número_Estação        282354 non-null  string
#  5   Latitude              282350 non-null  string
#  6   Longitude             282350 non-null  string
#  7   Código_Município      282354 non-null  string
#  8   UF                    282354 non-null  string
#  9   Potência(W)           282354 non-null  string
#  10  Cod_TipoAntena        282354 non-null  string
#  11  Polarização           282354 non-null  string
#  12  Raio_Antena           109716 non-null  string
#  13  Ganho_Antena          282354 non-null  string
#  14  FC_Antena             282354 non-null  string
#  15  Ang_MP_Antena         282354 non-null  string
#  16  Ângulo_Elevação       282354 non-null  string
#  17  Azimute               282354 non-null  string
#  18  Altura_Antena         282354 non-null  string
#  19  Perdas_Acessorias     282354 non-null  string
#  20  Tipo_Estação          282354 non-null  string
#  21  Tecnologia            282354 non-null  string
#  22  Frequência            282354 non-null  string
#  23  Frequência_Recepção   282352 non-null  string
#  24  Largura_Emissão(kHz)  282354 non-null  string
#  25  Classe_Emissão        282354 non-null  string
#  26  Início_Canal_Down     282354 non-null  string
#  27  Fim_Canal_Down        282354 non-null  string
#  28  Multiplicidade        282354 non-null  string
#  29  Blocos_Downlink       282354 non-null  string
#  30  Faixas                282354 non-null  string
#  31  Intervalo_Canal       282354 non-null  string
#  32  Offset                282354 non-null  string
#  33  Total                 282354 non-null  string
#  34  Coords_Valida_IBGE    282354 non-null  object
#  35  Latitude_IBGE         282350 non-null  string
#  36  Longitude_IBGE        282350 non-null  string
#  37  Status                282354 non-null  object
#  38  Num_Serviço           282354 non-null  object
#  39  Município_IBGE        282354 non-null  string
#  40  Fonte                 282354 non-null  object
#  41  Classe                282354 non-null  object
# dtypes: object(5), string(37)
# memory usage: 90.5+ MB

# %%
df = _filter_matlab(smp)

# %%
df = _format_matlab(df)

# %%
df[df.Description.str.contains('*', regex=False)]
# Out:
#              Id  Frequency   Latitude  Longitude  \
# 0            #1      454.5 -15.110000 -40.068401
# 1            #2      454.5 -15.022500 -42.372700
# 2            #3      454.5 -14.767800 -42.649799
# 3            #4      454.5 -14.571000 -42.943401
# 4            #5      454.5 -14.384700 -41.884201
# ...         ...        ...        ...        ...
# 282349  #282350     2690.0   0.034934 -51.069401
# 282350  #282351     2690.0   0.034934 -51.069401
# 282351  #282352     2690.0   0.939956 -60.438900
# 282352  #282353     2690.0   1.827660 -61.130402
# 282353  #282354     2690.0   2.823840 -60.675301
#
#                                               Description  Service  \
# 0       [DOC] L, ML, Claro S.A. (50409307637, 10026280...       10
# 1       [DOC] L, ML, Claro S.A. (50409307637, 10022640...       10
# 2       [DOC] L, ML, Claro S.A. (50409307637, 10021314...       10
# 3       [DOC] L, ML, Claro S.A. (50409307637, 10020029...       10
# 4       [DOC] L, ML, Claro S.A. (50409307637, 10022545...       10
# ...                                                   ...      ...
# 282349  [MOS] L, FB, Telefônica Brasil S.A. (504091462...       10
# 282350  [MOS] L, FB, Telefônica Brasil S.A. (504091462...       10
# 282351  [MOS] L, FB, Telefônica Brasil S.A. (504091462...       10
# 282352  [MOS] L, FB, Telefonica Brasil S.A. (504091462...       10
# 282353  [MOS] L, FB, Telefônica Brasil S.A. (504091462...       10
#
#            Station Class       BW
# 0       1002628048   G7W   5000.0
# 1       1002264003   G7W   5000.0
# 2       1002131429   G7W   5000.0
# 3       1002002904   G7W   5000.0
# 4       1002254539   G7W   5000.0
# ...            ...   ...      ...
# 282349   690246692   G7W    200.0
# 282350   695978241   G7W   5000.0
# 282351   691058440   G7W  20000.0
# 282352   687270995   G7W  20000.0
# 282353   442820496   G7W  20000.0
#
# [277334 rows x 9 columns]

# %%
df.to_parquet(folder / 'smp_processado.parquet.gzip', compression='gzip')
