# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path().cwd().parent))
# %load_ext autoreload
# %autoreload 2

# %%
import os
from pprint import pprint
from fastcore.xtras import Path
from time import perf_counter
import pandas as pd
from pymongo import MongoClient
from dotenv import find_dotenv, load_dotenv
from ydata_profiling import ProfileReport

# %%
load_dotenv(find_dotenv())
uri = os.environ["MONGO_URI"]
mongo_client = MongoClient(uri)
mongo_client.server_info()
database = mongo_client["sms"]
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[3], line 4
#       2 uri = os.environ["MONGO_URI"]
#       3 mongo_client = MongoClient(uri)
# ----> 4 mongo_client.server_info()
#       5 database = mongo_client["sms"]
#
# File ~/micromamba/envs/dados/lib/python3.11/site-packages/pymongo/mongo_client.py:1823, in MongoClient.server_info(self, session)
#    1811 def server_info(self, session: Optional[client_session.ClientSession] = None) -> Dict[str, Any]:
#    1812     """Get information about the MongoDB server we're connected to.
#    1813
#    1814     :Parameters:
#    (...)
#    1819        Added ``session`` parameter.
#    1820     """
#    1821     return cast(
#    1822         dict,
# -> 1823         self.admin.command(
#    1824             "buildinfo", read_preference=ReadPreference.PRIMARY, session=session
#    1825         ),
#    1826     )
#
# File ~/micromamba/envs/dados/lib/python3.11/site-packages/pymongo/_csot.py:106, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     104         with _TimeoutContext(timeout):
#     105             return func(self, *args, **kwargs)
# --> 106 return func(self, *args, **kwargs)
#
# File ~/micromamba/envs/dados/lib/python3.11/site-packages/pymongo/database.py:820, in Database.command(self, command, value, check, allowable_errors, read_preference, codec_options, session, comment, **kwargs)
#     818 if read_preference is None:
#     819     read_preference = (session and session._txn_read_preference()) or ReadPreference.PRIMARY
# --> 820 with self.__client._socket_for_reads(read_preference, session) as (
#     821     sock_info,
#     822     read_preference,
#     823 ):
#     824     return self._command(
#     825         sock_info,
#     826         command,
#    (...)
#     833         **kwargs,
#     834     )
#
# File ~/micromamba/envs/dados/lib/python3.11/site-packages/pymongo/mongo_client.py:1307, in MongoClient._socket_for_reads(self, read_preference, session)
#    1305 assert read_preference is not None, "read_preference must not be None"
#    1306 _ = self._get_topology()
# -> 1307 server = self._select_server(read_preference, session)
#    1308 return self._socket_from_server(read_preference, server, session)
#
# File ~/micromamba/envs/dados/lib/python3.11/site-packages/pymongo/mongo_client.py:1268, in MongoClient._select_server(self, server_selector, session, address)
#    1266             raise AutoReconnect("server %s:%d no longer available" % address)
#    1267     else:
# -> 1268         server = topology.select_server(server_selector)
#    1269     return server
#    1270 except PyMongoError as exc:
#    1271     # Server selection errors in a transaction are transient.
#
# File ~/micromamba/envs/dados/lib/python3.11/site-packages/pymongo/topology.py:271, in Topology.select_server(self, selector, server_selection_timeout, address)
#     269 def select_server(self, selector, server_selection_timeout=None, address=None):
#     270     """Like select_servers, but choose a random server if several match."""
# --> 271     server = self._select_server(selector, server_selection_timeout, address)
#     272     if _csot.get_timeout():
#     273         _csot.set_rtt(server.description.min_round_trip_time)
#
# File ~/micromamba/envs/dados/lib/python3.11/site-packages/pymongo/topology.py:260, in Topology._select_server(self, selector, server_selection_timeout, address)
#     259 def _select_server(self, selector, server_selection_timeout=None, address=None):
# --> 260     servers = self.select_servers(selector, server_selection_timeout, address)
#     261     if len(servers) == 1:
#     262         return servers[0]
#
# File ~/micromamba/envs/dados/lib/python3.11/site-packages/pymongo/topology.py:223, in Topology.select_servers(self, selector, server_selection_timeout, address)
#     220     server_timeout = server_selection_timeout
#     222 with self._lock:
# --> 223     server_descriptions = self._select_servers_loop(selector, server_timeout, address)
#     225     return [self.get_server_by_address(sd.address) for sd in server_descriptions]
#
# File ~/micromamba/envs/dados/lib/python3.11/site-packages/pymongo/topology.py:238, in Topology._select_servers_loop(self, selector, timeout, address)
#     235 while not server_descriptions:
#     236     # No suitable servers.
#     237     if timeout == 0 or now > end_time:
# --> 238         raise ServerSelectionTimeoutError(
#     239             f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     240         )
#     242     self._ensure_opened()
#     243     self._request_check_all()
#
# ServerSelectionTimeoutError: anatelbdro06:27017: [Errno -2] Name or service not known, Timeout: 5.0s, Topology Description: <TopologyDescription id: 64e76a591dbdccf49b628386, topology_type: Unknown, servers: [<ServerDescription ('anatelbdro06', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('anatelbdro06:27017: [Errno -2] Name or service not known')>]>

# %%
# for c in database.list_collection_names():
#     pprint(c)
#     pprint(database[c].find_one())
#     pprint(20*'=')

# %%
# database['licenciamento'].find_one()

# %%
MONGO_SMP = {
    "$and": [
        {"DataValidade": {"$nin": ["", None]}},
        {"Status.state": "LIC-LIC-01"},
        {"NumServico": "010"},
        {"FreqTxMHz": {"$nin": [None, "", 0]}},
        {"FreqTxMHz": {"$type": 1.0}}
    ]
}

COLS_SMP = {
    "NumAto": "Num_Ato",
    "NumFistel": "Fistel",
    "NomeEntidade": "Entidade",
    "SiglaUf": "UF",
    "NumEstacao": "Número_Estação",
    "CodMunicipio": "Código_Município",
    "DataValidade": "Validade_RF",
    # "FreqInicialMHz": "Frequência_Inicial",
    # "FreqCentralMHz": "Frequência_Central",
    "FreqTxMHz": "Frequência_Transmissão",
    "FreqRxMHz": "Frequência_Recepção",
    # "FreqFinalMHz": "Frequência_Final",
    "formId": "Tipo_Estação",
    "Tecnologia": "Tecnologia",
    "Latitude": "Latitude",
    "Longitude": "Longitude",
    "DesignacaoEmissao": "Designacao_Emissão",
    "PotenciaTransmissorWatts": "Potência(W)",
    "CodTipoAntena": "Cod_TipoAntena",
    "Polarizacao": "Polarização",
    "RaioAntena": "Raio_Antena",
    "GanhoAntena": "Ganho_Antena",
    "FrenteCostaAntena": "FC_Antena",
    "AnguloMeiaPotenciaAntena": "Ang_MP_Antena",
    "AnguloElevacao": "Ângulo_Elevação",
    "Azimute": "Azimute",
    "AlturaAntena": "Altura_Antena",
    "PerdasAcessorias": "Perdas_Acessorias",
}

DTYPE_SMP = {
    "NumAto": "category",
    "NumFistel": "category",
    "NomeEntidade": "category",
    "SiglaUf": "category",
    "NumEstacao": "string",
    "CodMunicipio": "category",
    "DataValidade": "category",
    "FreqInicialMHz": "category",
    "FreqCentralMHz": "category",
    "FreqFinalMHz": "category",
    "FreqTxMHz": "category",
    "FreqRxMHz": "category",
    "formId": "category",
    "Tecnologia": "category",
    "Latitude": "float",
    "Longitude": "float",
    "DesignacaoEmissao": "category",
    "PotenciaTransmissorWatts": "float",
    "CodTipoAntena": "category",
    "Polarizacao": "category",
    "RaioAntena": "float",
    "GanhoAntena": "float",
    "FrenteCostaAntena": "float",
    "AnguloMeiaPotenciaAntena": "float",
    "AnguloElevacao": "float",
    "Azimute": "float",
    "AlturaAntena": "float",
    "PerdasAcessorias": "float",
}

# %%
collection = database["licenciamento"]
query = collection.find(MONGO_SMP, projection={k: 1.0 for k in COLS_SMP}, limit=0)
df = pd.DataFrame(list(query))  # , columns=COLS_SMP.keys())
df.drop(columns=["_id"], inplace=True)

# %%
df
# Out:
#              NumAto DataValidade    NumFistel            NomeEntidade  \
# 0        16982008.0   2023-04-30  50409428698                 TIM S/A
# 1        16982008.0   2023-04-30  50409428698                 TIM S/A
# 2        16982008.0   2023-04-30  50409428698                 TIM S/A
# 3        16982008.0   2023-04-30  50409428698                 TIM S/A
# 4        16982008.0   2023-04-30  50409428698                 TIM S/A
# ...             ...          ...          ...                     ...
# 1946606   166262022   2028-11-29  50409146285  TELEFONICA BRASIL S.A.
# 1946607   166262022   2028-11-29  50409146285  TELEFONICA BRASIL S.A.
# 1946608    97432014   2028-11-29  50409146285  TELEFONICA BRASIL S.A.
# 1946609    97432014   2028-11-29  50409146285  TELEFONICA BRASIL S.A.
# 1946610    97432014   2028-11-29  50409146285  TELEFONICA BRASIL S.A.
#
#          NumEstacao  Latitude  Longitude FreqInicialMHz FreqFinalMHz  \
# 0              2119 -9.654881 -35.712517         2125.0       2135.0
# 1              2119 -9.654881 -35.712517         2125.0       2135.0
# 2              2119 -9.654881 -35.712517         2125.0       2135.0
# 3              2119 -9.654881 -35.712517         2125.0       2135.0
# 4              2119 -9.654881 -35.712517         2125.0       2135.0
# ...             ...       ...        ...            ...          ...
# 1946606  1012584507  -19.8785 -43.929722           None         None
# 1946607  1012584507  -19.8785 -43.929722           None         None
# 1946608   690061684 -19.93389  -43.97833           None         None
# 1946609   690061684 -19.93389  -43.97833           None         None
# 1946610   690061684 -19.93389  -43.97833           None         None
#
#         FreqCentralMHz  ... FrenteCostaAntena AnguloMeiaPotenciaAntena  \
# 0                 2130  ...              25.0                    60.00
# 1                 2130  ...              38.0                    66.50
# 2                 2130  ...              38.0                    66.50
# 3                 2130  ...              30.0                    70.50
# 4                 2130  ...              38.0                    66.50
# ...                ...  ...               ...                      ...
# 1946606            NaN  ...              25.0                     75.0
# 1946607            NaN  ...              25.0                     75.0
# 1946608            NaN  ...              25.0                     74.0
# 1946609            NaN  ...              25.0                     74.0
# 1946610            NaN  ...              25.0                     74.0
#
#         AnguloElevacao Azimute AlturaAntena PerdasAcessorias formId  \
# 0                 7.00    35.0         42.0                    base
# 1                14.00    35.0         42.0                    base
# 2                14.00   155.0         42.0                    base
# 3                 7.00   275.0         42.0                    base
# 4                14.00   275.0         42.0                    base
# ...                ...     ...          ...              ...    ...
# 1946606            0.0   175.0         19.0              0.0   base
# 1946607            0.0   275.0         19.0              0.0   base
# 1946608            8.0    15.0         19.0              0.0   base
# 1946609            8.0   135.0         19.0              0.0   base
# 1946610            6.0   240.0         19.0              0.0   base
#
#         Tecnologia FreqTxMHz FreqRxMHz
# 0            WCDMA    2135.0    2125.0
# 1            WCDMA    2135.0    2125.0
# 2            WCDMA    2135.0    2125.0
# 3            WCDMA    2135.0    2125.0
# 4            WCDMA    2135.0    2125.0
# ...            ...       ...       ...
# 1946606        LTE    2152.5    1962.5
# 1946607        LTE    2152.5    1962.5
# 1946608        LTE     788.0     733.0
# 1946609        LTE     788.0     733.0
# 1946610        LTE     788.0     733.0
#
# [1946611 rows x 28 columns]

# %%
dados = Path.cwd().parent / "dados"
dados.mkdir(parents=True, exist_ok=True)

df.astype("string").to_parquet(
    f"{dados}/smp_formated.parquet.gzip",
    compression="gzip",
    index=False,
)

# %%
df = pd.read_parquet(f"{dados}/smp_formated.parquet.gzip")

# %%
for k,v in DTYPE_SMP.items():
    if v == 'float':
        df[k] = df[k].str.replace(',', '.').str.extract(r'([\d*\.?\d*])')
        df.loc[df[k] == '.', k] = pd.NA

# %%
df = df.astype(DTYPE_SMP)
